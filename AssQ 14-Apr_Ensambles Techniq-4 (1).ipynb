# %% [markdown]
# # AssQ 14-Apr Ensamble Techniquies - 4

# %%
import pandas as pd
df = pd.read_csv("dataset.csv")
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
df.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# std      0.525860   22.905161    0.469794    1.161075    0.616226    1.022606
# min      0.000000   71.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000  133.500000    0.000000    0.000000    1.000000    0.000000
# 50%      1.000000  153.000000    0.000000    0.800000    1.000000    0.000000
# 75%      1.000000  166.000000    1.000000    1.600000    2.000000    1.000000
# max      2.000000  202.000000    1.000000    6.200000    2.000000    4.000000
#
#              thal      target
# count  303.000000  303.000000
# mean     2.313531    0.544554
# std      0.612277    0.498835
# min      0.000000    0.000000
# 25%      2.000000    0.000000
# 50%      2.000000    1.000000
# 75%      3.000000    1.000000
# max      3.000000    1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
## independent and dependent feature
X=df.drop(labels=['target'],axis=1)
y=df.target

# %%
df.head(3)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1

# %%
X.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal
# 0   0     1
# 1   0     2
# 2   0     2
# 3   0     2
# 4   0     2

# %%
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 298    0
# 299    0
# 300    0
# 301    0
# 302    0
# Name: target, Length: 303, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.30,random_state=42)

# %%
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer ## HAndle Missing Values
from sklearn.preprocessing import StandardScaler ## Feature Scaling
from sklearn.preprocessing import OneHotEncoder ## categorical to numerical
from sklearn.compose import ColumnTransformer

# %%
## feature Engineering Automation
## Numerical Pipelines
num_pipeline=Pipeline(
    steps=[
        ('imputer',SimpleImputer(strategy='median')), ##Missing Values
        ('scaler',StandardScaler()) ## feature Scaling
    ]

)

#categorical Pipeline
cat_pipeline=Pipeline(
                steps=[
                ('imputer',SimpleImputer(strategy='most_frequent')), ## handling Missing values
                ('onehotencoder',OneHotEncoder()) ## Categorical features to numerical
                ]

            )

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier

# %%
## Model Training Automation
models={
    'Random Forest':RandomForestClassifier(),
    'Logistic Regression':LogisticRegression(),
    'Decision Tree':DecisionTreeClassifier()

}

# %%
from sklearn.metrics import accuracy_score

# %%
def evaluate_model(X_train,y_train,X_test,y_test,models):
    
    report = {}
    for i in range(len(models)):
        model = list(models.values())[i]
        # Train model
        model.fit(X_train,y_train)

            

        # Predict Testing data
        y_test_pred =model.predict(X_test)

        # Get accuracy for test data prediction
       
        test_model_score = accuracy_score(y_test,y_test_pred)

        report[list(models.keys())[i]] =  test_model_score
            

            
    return report

# %%
import warnings 
warnings.filterwarnings('ignore')

# %%
evaluate_model(X_train,y_train,X_test,y_test,models)
# Out:
# {'Random Forest': 0.8241758241758241,
#  'Logistic Regression': 0.8131868131868132,
#  'Decision Tree': 0.7692307692307693}

# %%
classfier=RandomForestClassifier()

# %%
## Hypeparameter Tuning
params={'max_depth':[3,5,10,None],
              'n_estimators':[100,200,300],
               'criterion':['gini','entropy']
              }

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
cv=RandomizedSearchCV(classfier,param_distributions=params,scoring='accuracy',cv=5,verbose=3)
cv.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV 1/5] END criterion=entropy, max_depth=5, n_estimators=200;, score=0.860 total time=   0.3s
# [CV 2/5] END criterion=entropy, max_depth=5, n_estimators=200;, score=0.814 total time=   0.3s
# [CV 3/5] END criterion=entropy, max_depth=5, n_estimators=200;, score=0.738 total time=   0.3s
# [CV 4/5] END criterion=entropy, max_depth=5, n_estimators=200;, score=0.881 total time=   0.3s
# [CV 5/5] END criterion=entropy, max_depth=5, n_estimators=200;, score=0.786 total time=   0.3s
# [CV 1/5] END criterion=entropy, max_depth=5, n_estimators=100;, score=0.860 total time=   0.1s
# [CV 2/5] END criterion=entropy, max_depth=5, n_estimators=100;, score=0.837 total time=   0.1s
# [CV 3/5] END criterion=entropy, max_depth=5, n_estimators=100;, score=0.714 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_depth=5, n_estimators=100;, score=0.905 total time=   0.2s
# [CV 5/5] END criterion=entropy, max_depth=5, n_estimators=100;, score=0.762 total time=   0.1s
# [CV 1/5] END criterion=entropy, max_depth=10, n_estimators=200;, score=0.860 total time=   0.3s
# [CV 2/5] END criterion=entropy, max_depth=10, n_estimators=200;, score=0.837 total time=   0.3s
# [CV 3/5] END criterion=entropy, max_depth=10, n_estimators=200;, score=0.786 total time=   0.3s
# [CV 4/5] END criterion=entropy, max_depth=10, n_estimators=200;, score=0.905 total time=   0.3s
# [CV 5/5] END criterion=entropy, max_depth=10, n_estimators=200;, score=0.762 total time=   0.3s
# [CV 1/5] END criterion=gini, max_depth=3, n_estimators=200;, score=0.884 total time=   0.3s
# [CV 2/5] END criterion=gini, max_depth=3, n_estimators=200;, score=0.860 total time=   0.3s
# [CV 3/5] END criterion=gini, max_depth=3, n_estimators=200;, score=0.714 total time=   0.3s
# [CV 4/5] END criterion=gini, max_depth=3, n_estimators=200;, score=0.905 total time=   0.3s
# [CV 5/5] END criterion=gini, max_depth=3, n_estimators=200;, score=0.762 total time=   0.3s
# [CV 1/5] END criterion=gini, max_depth=10, n_estimators=200;, score=0.860 total time=   0.3s
# [CV 2/5] END criterion=gini, max_depth=10, n_estimators=200;, score=0.837 total time=   0.3s
# [CV 3/5] END criterion=gini, max_depth=10, n_estimators=200;, score=0.714 total time=   0.3s
# [CV 4/5] END criterion=gini, max_depth=10, n_estimators=200;, score=0.881 total time=   0.3s
# [CV 5/5] END criterion=gini, max_depth=10, n_estimators=200;, score=0.762 total time=   0.3s
# [CV 1/5] END criterion=entropy, max_depth=10, n_estimators=100;, score=0.884 total time=   0.2s
# [CV 2/5] END criterion=entropy, max_depth=10, n_estimators=100;, score=0.860 total time=   0.1s
# [CV 3/5] END criterion=entropy, max_depth=10, n_estimators=100;, score=0.762 total time=   0.1s
# [CV 4/5] END criterion=entropy, max_depth=10, n_estimators=100;, score=0.857 total time=   0.2s
# [CV 5/5] END criterion=entropy, max_depth=10, n_estimators=100;, score=0.762 total time=   0.1s
# [CV 1/5] END criterion=entropy, max_depth=3, n_estimators=300;, score=0.860 total time=   0.4s
# [CV 2/5] END criterion=entropy, max_depth=3, n_estimators=300;, score=0.860 total time=   0.4s
# [CV 3/5] END criterion=entropy, max_depth=3, n_estimators=300;, score=0.738 total time=   0.4s
# [CV 4/5] END criterion=entropy, max_depth=3, n_estimators=300;, score=0.905 total time=   0.4s
# [CV 5/5] END criterion=entropy, max_depth=3, n_estimators=300;, score=0.762 total time=   0.4s
# [CV 1/5] END criterion=gini, max_depth=10, n_estimators=300;, score=0.884 total time=   0.4s
# [CV 2/5] END criterion=gini, max_depth=10, n_estimators=300;, score=0.837 total time=   0.4s
# [CV 3/5] END criterion=gini, max_depth=10, n_estimators=300;, score=0.762 total time=   0.4s
# [CV 4/5] END criterion=gini, max_depth=10, n_estimators=300;, score=0.881 total time=   0.4s
# [CV 5/5] END criterion=gini, max_depth=10, n_estimators=300;, score=0.762 total time=   0.4s
# [CV 1/5] END criterion=entropy, max_depth=None, n_estimators=300;, score=0.837 total time=   0.4s
# [CV 2/5] END criterion=entropy, max_depth=None, n_estimators=300;, score=0.837 total time=   0.4s
# [CV 3/5] END criterion=entropy, max_depth=None, n_estimators=300;, score=0.714 total time=   0.4s
# [CV 4/5] END criterion=entropy, max_depth=None, n_estimators=300;, score=0.881 total time=   0.4s
# [CV 5/5] END criterion=entropy, max_depth=None, n_estimators=300;, score=0.762 total time=   0.4s
# [CV 1/5] END criterion=entropy, max_depth=None, n_estimators=100;, score=0.860 total time=   0.2s
# [CV 2/5] END criterion=entropy, max_depth=None, n_estimators=100;, score=0.791 total time=   0.2s
# [CV 3/5] END criterion=entropy, max_depth=None, n_estimators=100;, score=0.738 total time=   0.1s
# [CV 4/5] END criterion=entropy, max_depth=None, n_estimators=100;, score=0.881 total time=   0.2s
# [CV 5/5] END criterion=entropy, max_depth=None, n_estimators=100;, score=0.762 total time=   0.1s
# RandomizedSearchCV(cv=5, estimator=RandomForestClassifier(),
#                    param_distributions={'criterion': ['gini', 'entropy'],
#                                         'max_depth': [3, 5, 10, None],
#                                         'n_estimators': [100, 200, 300]},
#                    scoring='accuracy', verbose=3)

# %%
cv.best_params_
# Out:
# {'n_estimators': 200, 'max_depth': 10, 'criterion': 'entropy'}

# %%
df.head(2)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
